# %%
import great_expectations as gx

context = gx.get_context()

# %%
result = context.run_checkpoint(checkpoint_name="station_1_checkpoint")
# Out:
# Calculating Metrics:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
result
# Out:
# {
#   "run_id": {
#     "run_name": "20240422-132546-my-run-name-template",
#     "run_time": "2024-04-22T15:25:46.984729+02:00"
#   },
#   "run_results": {
#     "ValidationResultIdentifier::station_1_suite/20240422-132546-my-run-name-template/20240422T132546.984729Z/da9adfc1ec904473705e240fc2f90efd": {
#       "validation_result": {
#         "success": false,
#         "results": [
#           {
#             "success": false,
#             "expectation_config": {
#               "expectation_type": "expect_table_row_count_to_be_between",
#               "kwargs": {
#                 "max_value": 392,
#                 "min_value": 392,
#                 "batch_id": "da9adfc1ec904473705e240fc2f90efd"
#               },
#               "meta": {
#                 "profiler_details": {
#                   "metric_configuration": {
#                     "domain_kwargs": {},
#                     "metric_name": "table.row_count",
#                     "metric_value_kwargs": null
#                   },
#                   "num_batches": 1
#                 }
#               }
#             },
#             "result": {
#               "observed_value": 394
#             },
#             "meta": {},
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           },
#           {
#             "success": true,
#             "expectation_config": {
#               "expectation_type": "expect_table_columns_to_match_set",
#               "kwargs": {
#                 "column_set": [
#                   "bike_stands",
#                   "apparent_temperature",
#                   "rain",
#                   "surface_pressure",
#                   "precipitation_probability",
#                   "temperature",
#                   "dew_point",
#                   "relative_humidity",
#                   "date",
#                   "available_bike_stands"
#                 ],
#                 "exact_match": null,
#                 "batch_id": "da9adfc1ec904473705e240fc2f90efd"
#               },
#               "meta": {
#                 "profiler_details": {
#                   "success_ratio": 1.0
#                 }
#               }
#             },
#             "result": {
#               "observed_value": [
#                 "date",
#                 "bike_stands",
#                 "available_bike_stands",
#                 "temperature",
#                 "relative_humidity",
#                 "dew_point",
#                 "apparent_temperature",
#                 "precipitation_probability",
#                 "rain",
#                 "surface_pressure"
#               ]
#             },
#             "meta": {},
#             "exception_info": {
#               "raised_exception": false,
#               "exception_traceback": null,
#               "exception_message": null
#             }
#           }
#         ],
#         "evaluation_parameters": {},
#         "statistics": {
#           "evaluated_expectations": 2,
#           "successful_expectations": 1,
#           "unsuccessful_expectations": 1,
#           "success_percent": 50.0
#         },
#         "meta": {
#           "great_expectations_version": "0.18.12",
#           "expectation_suite_name": "station_1_suite",
#           "run_id": {
#             "run_name": "20240422-132546-my-run-name-template",
#             "run_time": "2024-04-22T15:25:46.984729+02:00"
#           },
#           "batch_spec": {
#             "path": "c:\\Users\\trdin\\OneDrive\\Namizje\\mag 2semester\\INZENIRSTVO INTELIGENTNIH SISTEMOV\\naloga1\\gx\\..\\data\\processed\\station_17.csv"
#           },
#           "batch_markers": {
#             "ge_load_time": "20240422T132546.996738Z",
#             "pandas_data_fingerprint": "f7d303981a551cec98d5bc57b1ae2d26"
#           },
#           "active_batch_definition": {
#             "datasource_name": "my_datasource",
#             "data_connector_name": "default_inferred_data_connector_name",
#             "data_asset_name": "station_17.csv",
#             "batch_identifiers": {}
#           },
#           "validation_time": "20240422T132547.015262Z",
#           "checkpoint_name": "station_1_checkpoint",
#           "validation_id": null,
#           "checkpoint_id": null
#         }
#       },
#       "actions_results": {
#         "store_validation_result": {
#           "class": "StoreValidationResultAction"
#         },
#         "store_evaluation_params": {
#           "class": "StoreEvaluationParametersAction"
#         },
#         "update_data_docs": {
#           "local_site": "file://c:\\Users\\trdin\\OneDrive\\Namizje\\mag 2semester\\INZENIRSTVO INTELIGENTNIH SISTEMOV\\naloga1\\gx\\uncommitted/data_docs/local_site/validations%5Cstation_1_suite%5C20240422-132546-my-run-name-template%5C20240422T132546.984729Z%5Cda9adfc1ec904473705e240fc2f90efd.html",
#           "class": "UpdateDataDocsAction"
#         }
#       }
#     }
#   },
#   "checkpoint_config": {
#     "runtime_configuration": {},
#     "site_names": null,
#     "name": "station_1_checkpoint",
#     "config_version": 1.0,
#     "validations": [
#       {
#         "name": null,
#         "batch_request": {
#           "datasource_name": "my_datasource",
#           "data_connector_name": "default_inferred_data_connector_name",
#           "data_asset_name": "station_17.csv",
#           "data_connector_query": {
#             "index": -1
#           }
#         },
#         "id": null,
#         "expectation_suite_ge_cloud_id": null,
#         "expectation_suite_name": "station_1_suite"
#       }
#     ],
#     "class_name": "SimpleCheckpoint",
#     "batch_request": {},
#     "notify_with": null,
#     "action_list": [
#       {
#         "name": "store_validation_result",
#         "action": {
#           "class_name": "StoreValidationResultAction"
#         }
#       },
#       {
#         "name": "store_evaluation_params",
#         "action": {
#           "class_name": "StoreEvaluationParametersAction"
#         }
#       },
#       {
#         "name": "update_data_docs",
#         "action": {
#           "class_name": "UpdateDataDocsAction"
#         }
#       }
#     ],
#     "expectation_suite_name": null,
#     "default_validation_id": null,
#     "ge_cloud_id": null,
#     "expectation_suite_ge_cloud_id": null,
#     "evaluation_parameters": {},
#     "template_name": null,
#     "slack_webhook": null,
#     "profilers": [],
#     "notify_on": null,
#     "run_name_template": "%Y%m%d-%H%M%S-my-run-name-template",
#     "module_name": "great_expectations.checkpoint"
#   },
#   "success": false
# }

# %%
if not result["success"]:
    print("Validation failed!")

print("Validation succeeded!")
# Out:
# Validation failed!
# Validation succeeded!
